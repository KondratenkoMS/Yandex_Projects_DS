# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Описание-данных" data-toc-modified-id="Описание-данных-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Описание данных</a></span><ul class="toc-item"><li><span><a href="#Технологический-процесс" data-toc-modified-id="Технологический-процесс-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Технологический процесс</a></span></li><li><span><a href="#Параметры-этапов" data-toc-modified-id="Параметры-этапов-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Параметры этапов</a></span></li><li><span><a href="#Наименование-признаков-должно-быть-такое:" data-toc-modified-id="Наименование-признаков-должно-быть-такое:-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Наименование признаков должно быть такое:</a></span></li><li><span><a href="#Возможные-значения-для-блока-[этап]:" data-toc-modified-id="Возможные-значения-для-блока-[этап]:-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Возможные значения для блока [этап]:</a></span></li><li><span><a href="#Возможные-значения-для-блока-[тип_параметра]:" data-toc-modified-id="Возможные-значения-для-блока-[тип_параметра]:-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>Возможные значения для блока [тип_параметра]:</a></span></li></ul></li><li><span><a href="#Подготовка-данных" data-toc-modified-id="Подготовка-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Подготовка данных</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#1.2.-Проверьте,-что-эффективность-обогащения-рассчитана-правильно.-Вычислите-её-на-обучающей-выборке-для-признака-rougher.output.recovery.-Найдите-MAE-между-вашими-расчётами-и-значением-признака.-Опишите-выводы." data-toc-modified-id="1.2.-Проверьте,-что-эффективность-обогащения-рассчитана-правильно.-Вычислите-её-на-обучающей-выборке-для-признака-rougher.output.recovery.-Найдите-MAE-между-вашими-расчётами-и-значением-признака.-Опишите-выводы.-2.0.1"><span class="toc-item-num">2.0.1&nbsp;&nbsp;</span>1.2. Проверьте, что эффективность обогащения рассчитана правильно. Вычислите её на обучающей выборке для признака rougher.output.recovery. Найдите MAE между вашими расчётами и значением признака. Опишите выводы.</a></span></li><li><span><a href="#1.3.-Проанализируйте-признаки,-недоступные-в-тестовой-выборке.-Что-это-за-параметры?-К-какому-типу-относятся?" data-toc-modified-id="1.3.-Проанализируйте-признаки,-недоступные-в-тестовой-выборке.-Что-это-за-параметры?-К-какому-типу-относятся?-2.0.2"><span class="toc-item-num">2.0.2&nbsp;&nbsp;</span>1.3. Проанализируйте признаки, недоступные в тестовой выборке. Что это за параметры? К какому типу относятся?</a></span></li><li><span><a href="#1.4.-Проведите-предобработку-данных." data-toc-modified-id="1.4.-Проведите-предобработку-данных.-2.0.3"><span class="toc-item-num">2.0.3&nbsp;&nbsp;</span>1.4. Проведите предобработку данных.</a></span></li></ul></li></ul></li><li><span><a href="#Анализ-данных" data-toc-modified-id="Анализ-данных-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Анализ данных</a></span></li><li><span><a href="#Модель" data-toc-modified-id="Модель-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Модель</a></span></li><li><span><a href="#Чек-лист-готовности-проекта" data-toc-modified-id="Чек-лист-готовности-проекта-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Чек-лист готовности проекта</a></span></li></ul></div>

# %% [markdown]
# # Восстановление золота из руды

# %% [markdown]
# Подготовьте прототип модели машинного обучения для «Цифры». Компания разрабатывает решения для эффективной работы промышленных предприятий.
#
# Модель должна предсказать коэффициент восстановления золота из золотосодержащей руды. Используйте данные с параметрами добычи и очистки.
#
# Модель поможет оптимизировать производство, чтобы не запускать предприятие с убыточными характеристиками.
#
# Вам нужно:
#
# 1. Подготовить данные;
# 2. Провести исследовательский анализ данных;
# 3. Построить и обучить модель.
#
# Чтобы выполнить проект, обращайтесь к библиотекам *pandas*, *matplotlib* и *sklearn.* Вам поможет их документация.

# %% [markdown]
# ## Описание данных
# ### Технологический процесс
#     Rougher feed — исходное сырье
#     Rougher additions (или reagent additions) — флотационные реагенты: Xanthate, Sulphate, Depressant
#     Xanthate — ксантогенат (промотер, или активатор флотации);
#     Sulphate — сульфат (на данном производстве сульфид натрия);
#     Depressant — депрессант (силикат натрия).
#     Rougher process (англ. «грубый процесс») — флотация
#     Rougher tails — отвальные хвосты
#     Float banks — флотационная установка
#     Cleaner process — очистка
#     Rougher Au — черновой концентрат золота
#     Final Au — финальный концентрат золота
# ### Параметры этапов
#     air amount — объём воздуха
#     fluid levels — уровень жидкости
#     feed size — размер гранул сырья
#     feed rate — скорость подачи
# Наименование признаков
# ### Наименование признаков должно быть такое:
#     [этап].[тип_параметра].[название_параметра]
#     Пример: rougher.input.feed_ag
# ### Возможные значения для блока [этап]:
#     rougher — флотация
#     primary_cleaner — первичная очистка
#     secondary_cleaner — вторичная очистка
#     final — финальные характеристики
# ### Возможные значения для блока [тип_параметра]:
#     input — параметры сырья
#     output — параметры продукта
#     state — параметры, характеризующие текущее состояние этапа
#     calculation — расчётные характеристики

# %% [markdown]
# ## Подготовка данных

# %%
import pandas as pd
import numpy as np
import random
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from sklearn.metrics import f1_score
from sklearn.utils import shuffle
from sklearn.metrics import roc_auc_score
import warnings
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import roc_auc_score, roc_curve
from sklearn.model_selection import cross_val_score
from sklearn.metrics import fbeta_score, make_scorer
#models
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.neural_network import MLPRegressor

# %%
warnings.filterwarnings("ignore")
pd.options.mode.chained_assignment = None

# %%
try:
    data_train = pd.read_csv('/datasets/gold_recovery_train.csv')
    data_test = pd.read_csv('/datasets/gold_recovery_test.csv')
    data_full = pd.read_csv('/datasets/gold_recovery_full.csv')
except:
    data_train = pd.read_csv('C:/Users/Mikhail/оформление/Сборный проект - 2/gold_recovery_train.csv')
    data_test = pd.read_csv('C:/Users/Mikhail/оформление/Сборный проект - 2/gold_recovery_test.csv')
    data_full = pd.read_csv('C:/Users/Mikhail/оформление/Сборный проект - 2/gold_recovery_full.csv')
#_new
data_train = data_train.drop(['Unnamed: 0'], axis=1)
data_test = data_test.drop(['Unnamed: 0'], axis=1)
data_full = data_full.drop(['Unnamed: 0'], axis=1)

# %%
data_train.head()
# Out:
#                   date  final.output.concentrate_ag  \
# 0  2016-01-15 00:00:00                     6.055403
# 1  2016-01-15 01:00:00                     6.029369
# 2  2016-01-15 02:00:00                     6.055926
# 3  2016-01-15 03:00:00                     6.047977
# 4  2016-01-15 04:00:00                     6.148599
#
#    final.output.concentrate_pb  final.output.concentrate_sol  \
# 0                     9.889648                      5.507324
# 1                     9.968944                      5.257781
# 2                    10.213995                      5.383759
# 3                     9.977019                      4.858634
# 4                    10.142511                      4.939416
#
#    final.output.concentrate_au  final.output.recovery  final.output.tail_ag  \
# 0                    42.192020              70.541216             10.411962
# 1                    42.701629              69.266198             10.462676
# ...

# %%
data_test.head()
# Out:
#                   date  primary_cleaner.input.sulfate  \
# 0  2016-09-01 00:59:59                     210.800909
# 1  2016-09-01 01:59:59                     215.392455
# 2  2016-09-01 02:59:59                     215.259946
# 3  2016-09-01 03:59:59                     215.336236
# 4  2016-09-01 04:59:59                     199.099327
#
#    primary_cleaner.input.depressant  primary_cleaner.input.feed_size  \
# 0                         14.993118                         8.080000
# 1                         14.987471                         8.080000
# 2                         12.884934                         7.786667
# 3                         12.006805                         7.640000
# 4                         10.682530                         7.530000
#
#    primary_cleaner.input.xanthate  primary_cleaner.state.floatbank8_a_air  \
# 0                        1.005021                             1398.981301
# ...

# %%
data_full.head()
# Out:
#                   date  final.output.concentrate_ag  \
# 0  2016-01-15 00:00:00                     6.055403
# 1  2016-01-15 01:00:00                     6.029369
# 2  2016-01-15 02:00:00                     6.055926
# 3  2016-01-15 03:00:00                     6.047977
# 4  2016-01-15 04:00:00                     6.148599
#
#    final.output.concentrate_pb  final.output.concentrate_sol  \
# 0                     9.889648                      5.507324
# 1                     9.968944                      5.257781
# 2                    10.213995                      5.383759
# 3                     9.977019                      4.858634
# 4                    10.142511                      4.939416
#
#    final.output.concentrate_au  final.output.recovery  final.output.tail_ag  \
# 0                    42.192020              70.541216             10.411962
# 1                    42.701629              69.266198             10.462676
# ...

# %%
def miss_sorted(data):
    report = data.isna().sum().to_frame()
    report = report.rename(columns = {0: 'missing_values'})
    report['% of total'] = (report['missing_values'] / data.shape[0]).round(2)
    print(report.sort_values(by = 'missing_values', ascending = False))

# %%
def describe(data):
    print(data.describe())

# %% [markdown]
# #### 1.2. Проверьте, что эффективность обогащения рассчитана правильно. Вычислите её на обучающей выборке для признака rougher.output.recovery. Найдите MAE между вашими расчётами и значением признака. Опишите выводы.

# %%
data_train_recovery = data_train[['rougher.output.concentrate_au',
                                               'rougher.input.feed_au',
                                               'rougher.output.tail_au',
                                               'rougher.output.recovery']]

# %%
data_train_recovery
# Out:
#        rougher.output.concentrate_au  rougher.input.feed_au  \
# 0                          19.793808               6.486150
# 1                          20.050975               6.478583
# 2                          19.737170               6.362222
# 3                          19.320810               6.118189
# 4                          19.216101               5.663707
# ...                              ...                    ...
# 16855                      18.603550               5.335862
# 16856                      18.441436               4.838619
# 16857                      15.111231               4.525061
# 16858                      17.834772               4.362781
# 16859                      17.804134               4.365491
#
#        rougher.output.tail_au  rougher.output.recovery
# 0                    1.170244                87.107763
# 1                    1.184827                86.843261
# 2                    1.162562                86.842308
# ...

# %% [markdown]
# Эффективность обогащения рассчитывается по формуле
#
# Recovery = C * (F - T) / F * (C - T) * 100
#
#     где:
#     C  - доля золота в концентрате после флотации/очистки (rougher.output.concentrate_au)
#     F  - доля золота в сырье/концентрате до флотации/очистки (rougher.input.feed_au)
#     T  - доля золота в отвальных хвостах после флотации/очистки (rougher.output.tail_au)

# %%
def recovery_calculate(data):
    for i in range(len(data)):
        C = data['rougher.output.concentrate_au']
        F = data['rougher.input.feed_au']
        T = data['rougher.output.tail_au']
        recovery = (C * (F - T)) / (F * (C - T)) * 100
    return recovery

# %%
data_train_recovery['calc'] =  data_train_recovery.apply(recovery_calculate, axis=1)

# %%
data_train_recovery
# Out:
#        rougher.output.concentrate_au  rougher.input.feed_au  \
# 0                          19.793808               6.486150
# 1                          20.050975               6.478583
# 2                          19.737170               6.362222
# 3                          19.320810               6.118189
# 4                          19.216101               5.663707
# ...                              ...                    ...
# 16855                      18.603550               5.335862
# 16856                      18.441436               4.838619
# 16857                      15.111231               4.525061
# 16858                      17.834772               4.362781
# 16859                      17.804134               4.365491
#
#        rougher.output.tail_au  rougher.output.recovery       calc
# 0                    1.170244                87.107763  87.107763
# 1                    1.184827                86.843261  86.843261
# ...

# %% [markdown]
# Для подсчета МАЕ нам необходимо избавиться от пропусков, для рассчетов просто их выкинием.

# %%
data_train_recovery_no_NA = data_train_recovery.dropna(axis=0)

# %%
data_train_recovery_no_NA
# Out:
#        rougher.output.concentrate_au  rougher.input.feed_au  \
# 0                          19.793808               6.486150
# 1                          20.050975               6.478583
# 2                          19.737170               6.362222
# 3                          19.320810               6.118189
# 4                          19.216101               5.663707
# ...                              ...                    ...
# 16855                      18.603550               5.335862
# 16856                      18.441436               4.838619
# 16857                      15.111231               4.525061
# 16858                      17.834772               4.362781
# 16859                      17.804134               4.365491
#
#        rougher.output.tail_au  rougher.output.recovery       calc
# 0                    1.170244                87.107763  87.107763
# 1                    1.184827                86.843261  86.843261
# ...

# %%
from sklearn.metrics import mean_absolute_error
y_true = data_train_recovery_no_NA['rougher.output.recovery']
y_pred = data_train_recovery_no_NA['calc']
mean_absolute_error(y_true, y_pred)
# Out:
# 9.720555477409947e-15

# %% [markdown]
# Средняя абсолютная ошибка крайне мала, данные таблицы и данные полученые вычислением верны.

# %% [markdown]
# #### 1.3. Проанализируйте признаки, недоступные в тестовой выборке. Что это за параметры? К какому типу относятся?

# %% [markdown]
# 1. Модель должна предсказать коэффициент восстановления золота из золотосодержащей руды.
# 2. В тестовом df нет целевого показателя в виде final.output.recovery,rougher.output.recovery
# 3. В обучающем есть лишние столбцы, которых нет в тестово т.к. они расчитываются уже после всего процесса.

# %% [markdown]
# #### 1.4. Проведите предобработку данных.

# %%
miss_sorted(data_train[['rougher.output.recovery', 'final.output.recovery']])
# Out:
#                          missing_values  % of total
# rougher.output.recovery            2573        0.15
# final.output.recovery              1521        0.09

# %% [markdown]
#     data_train:
#     rougher.output.recovery   - 15% пропусков
#     final.output.recovery  - 9% пропусков
# 1. Самое простое - удалить пропуски и потом сделать upsample данных для восполнения потерь в данных
# 2. Заполнить из полного датасета значениями, если они есть для данных временных значений.
# 3. Между признаками есть мультиколлинеарность, удаление их в итоге повысила точность, поэтому коррелирующие признаки удалены.
# 4. Время можно перевести в индексы
# 5. В train датасете есть признаки, которые расчитываются после, их можно выкинуть и оставить одинаковое количество столбцов, как в тестовом датасете

# %%
sns.displot(data=data_full[['rougher.output.recovery', 'final.output.recovery']])
describe(data_full[['rougher.output.recovery', 'final.output.recovery']])
# Out:
#        rougher.output.recovery  final.output.recovery
# count             19597.000000           20753.000000
# mean                 83.078122              67.447488
# std                  14.661880              11.616034
# min                   0.000000               0.000000
# 25%                  80.941306              63.282393
# 50%                  86.144121              68.322258
# 75%                  89.987561              72.950836
# max                 100.000000             100.000000

# %%
data_full = data_full.fillna(method='ffill')

# %%
sns.displot(data=data_full[['rougher.output.recovery', 'final.output.recovery']])
describe(data_full[['rougher.output.recovery', 'final.output.recovery']])
# Out:
#        rougher.output.recovery  final.output.recovery
# count             22716.000000           22716.000000
# mean                 81.365546              66.475263
# std                  17.605929              13.042781
# min                   0.000000               0.000000
# 25%                  80.112940              62.258453
# 50%                  85.830386              67.981407
# 75%                  89.732511              72.941119
# max                 100.000000             100.000000

# %% [markdown]
# 1. После заполнения пропусков воявились некоторые шумы, но среднеквадратичные отклонения и средние распределения изменились слабо, наименьшее отклонение получилось у метода 'ffil'
# 2. Так же можно отметить, что распределение нормальное, но есть выбросы в районе 0, возможно в эти моменты только начинался процесс и поэтому нет эффективность обогащения даже на rougher отсутсвует.

# %%
data_test = data_test.set_index('date')
data_full = data_full.set_index('date')
data_train = data_train.set_index('date')

# %%
data_full_target = data_full[['final.output.recovery','rougher.output.recovery']]
data_test = data_test.join(data_full_target)

# %%
data_test.head(2)
# Out:
#                      primary_cleaner.input.sulfate  \
# date
# 2016-09-01 00:59:59                     210.800909
# 2016-09-01 01:59:59                     215.392455
#
#                      primary_cleaner.input.depressant  \
# date
# 2016-09-01 00:59:59                         14.993118
# 2016-09-01 01:59:59                         14.987471
#
#                      primary_cleaner.input.feed_size  \
# date
# 2016-09-01 00:59:59                             8.08
# 2016-09-01 01:59:59                             8.08
#
#                      primary_cleaner.input.xanthate  \
# date
# 2016-09-01 00:59:59                        1.005021
# 2016-09-01 01:59:59                        0.990469
#
#                      primary_cleaner.state.floatbank8_a_air  \
# date
# 2016-09-01 00:59:59                             1398.981301
# 2016-09-01 01:59:59                             1398.777912
#
#                      primary_cleaner.state.floatbank8_a_level  \
# date
# ...

# %%
list_of_columns = data_train.columns.tolist()
drop_list = []

for col in list_of_columns:
    if col not in data_test.columns:
        drop_list.append(col)

# %%
drop_list
# Out:
# ['final.output.concentrate_ag',
#  'final.output.concentrate_pb',
#  'final.output.concentrate_sol',
#  'final.output.concentrate_au',
#  'final.output.tail_ag',
#  'final.output.tail_pb',
#  'final.output.tail_sol',
#  'final.output.tail_au',
#  'primary_cleaner.output.concentrate_ag',
#  'primary_cleaner.output.concentrate_pb',
#  'primary_cleaner.output.concentrate_sol',
#  'primary_cleaner.output.concentrate_au',
#  'primary_cleaner.output.tail_ag',
#  'primary_cleaner.output.tail_pb',
#  'primary_cleaner.output.tail_sol',
#  'primary_cleaner.output.tail_au',
#  'rougher.calculation.sulfate_to_au_concentrate',
#  'rougher.calculation.floatbank10_sulfate_to_au_feed',
#  'rougher.calculation.floatbank11_sulfate_to_au_feed',
#  'rougher.calculation.au_pb_ratio',
#  'rougher.output.concentrate_ag',
#  'rougher.output.concentrate_pb',
#  'rougher.output.concentrate_sol',
#  'rougher.output.concentrate_au',
#  'rougher.output.tail_ag',
#  'rougher.output.tail_pb',
# ...

# %%
data_train.drop(drop_list, axis=1, inplace=True)
data_train.head(2)
# Out:
#                      final.output.recovery  primary_cleaner.input.sulfate  \
# date
# 2016-01-15 00:00:00              70.541216                     127.092003
# 2016-01-15 01:00:00              69.266198                     125.629232
#
#                      primary_cleaner.input.depressant  \
# date
# 2016-01-15 00:00:00                         10.128295
# 2016-01-15 01:00:00                         10.296251
#
#                      primary_cleaner.input.feed_size  \
# date
# 2016-01-15 00:00:00                             7.25
# 2016-01-15 01:00:00                             7.25
#
#                      primary_cleaner.input.xanthate  \
# date
# 2016-01-15 00:00:00                        0.988759
# 2016-01-15 01:00:00                        1.002663
#
#                      primary_cleaner.state.floatbank8_a_air  \
# date
# 2016-01-15 00:00:00                             1549.775757
# 2016-01-15 01:00:00                             1576.166671
#
# ...

# %%
miss_sorted(data_test)
# Out:
#                                             missing_values  % of total
# rougher.input.floatbank11_xanthate                     353        0.06
# primary_cleaner.input.sulfate                          302        0.05
# primary_cleaner.input.depressant                       284        0.05
# rougher.input.floatbank10_sulfate                      257        0.04
# primary_cleaner.input.xanthate                         166        0.03
# rougher.input.floatbank10_xanthate                     123        0.02
# rougher.input.feed_sol                                  67        0.01
# rougher.input.floatbank11_sulfate                       55        0.01
# rougher.input.feed_rate                                 40        0.01
# secondary_cleaner.state.floatbank3_a_air                34        0.01
# secondary_cleaner.state.floatbank2_b_air                23        0.00
# rougher.input.feed_size                                 22        0.00
# ...

# %%
miss_sorted(data_train)
# Out:
#                                             missing_values  % of total
# rougher.output.recovery                               2573        0.15
# rougher.input.floatbank11_xanthate                    1904        0.11
# final.output.recovery                                 1521        0.09
# primary_cleaner.input.sulfate                         1307        0.08
# primary_cleaner.input.depressant                      1262        0.07
# rougher.input.floatbank10_sulfate                     1044        0.06
# primary_cleaner.input.xanthate                         985        0.06
# rougher.input.floatbank11_sulfate                      623        0.04
# rougher.state.floatbank10_e_air                        603        0.04
# rougher.input.feed_rate                                513        0.03
# rougher.input.feed_size                                417        0.02
# secondary_cleaner.state.floatbank2_a_air               363        0.02
# ...

# %% [markdown]
# 1. В тестовой df остались пропуски, заполним остатки update
# 2. в тренировочном df заполнить пропуски иак же

# %%
data_train.update(data_full, join='left', overwrite=False, filter_func=None, errors='ignore')
data_test.update(data_full, join='left', overwrite=False, filter_func=None, errors='ignore')

# %%
miss_sorted(data_train)
# Out:
#                                             missing_values  % of total
# final.output.recovery                                    0         0.0
# secondary_cleaner.state.floatbank3_a_air                 0         0.0
# rougher.state.floatbank10_c_level                        0         0.0
# rougher.state.floatbank10_d_air                          0         0.0
# rougher.state.floatbank10_d_level                        0         0.0
# rougher.state.floatbank10_e_air                          0         0.0
# rougher.state.floatbank10_e_level                        0         0.0
# rougher.state.floatbank10_f_air                          0         0.0
# rougher.state.floatbank10_f_level                        0         0.0
# secondary_cleaner.state.floatbank2_a_air                 0         0.0
# secondary_cleaner.state.floatbank2_a_level               0         0.0
# secondary_cleaner.state.floatbank2_b_air                 0         0.0
# ...

# %%
miss_sorted(data_test)
# Out:
#                                             missing_values  % of total
# primary_cleaner.input.sulfate                            0         0.0
# secondary_cleaner.state.floatbank3_b_air                 0         0.0
# rougher.state.floatbank10_d_level                        0         0.0
# rougher.state.floatbank10_e_air                          0         0.0
# rougher.state.floatbank10_e_level                        0         0.0
# rougher.state.floatbank10_f_air                          0         0.0
# rougher.state.floatbank10_f_level                        0         0.0
# secondary_cleaner.state.floatbank2_a_air                 0         0.0
# secondary_cleaner.state.floatbank2_a_level               0         0.0
# secondary_cleaner.state.floatbank2_b_air                 0         0.0
# secondary_cleaner.state.floatbank2_b_level               0         0.0
# secondary_cleaner.state.floatbank3_a_air                 0         0.0
# ...

# %%
sns.displot(data=data_train[['rougher.output.recovery', 'final.output.recovery']])
sns.displot(data=data_test[['rougher.output.recovery', 'final.output.recovery']])

# %%
data_train = data_train[(data_train['rougher.output.recovery'] != 0 ) & (data_train['final.output.recovery'] != 0)]
data_test = data_test[(data_test['rougher.output.recovery'] != 0 ) & (data_test['final.output.recovery'] != 0)]

# %%
sns.displot(data=data_train[['rougher.output.recovery', 'final.output.recovery']])
sns.displot(data=data_test[['rougher.output.recovery', 'final.output.recovery']])

# %% [markdown]
# **Проверка на мультиколлинеарность признаков**

# %%
drop_list_corr = []

def correlation(dataset, threshold):
    col_corr = set() 
    corr_matrix = dataset.corr()
    for i in range(len(corr_matrix.columns)):
        for j in range(i):
            if (corr_matrix.iloc[i, j] >= threshold) and (corr_matrix.columns[j] not in col_corr):
                colname = corr_matrix.columns[i] 
                col_corr.add(colname)
                if colname in dataset.columns:
                    drop_list_corr.append(dataset[colname])
                    del dataset[colname] 
    print(dataset)

# %%
df = data_full.drop(drop_list, axis=1)

# %%
correlation(df, 0.8)
# Out:
#                      final.output.recovery  primary_cleaner.input.sulfate  \
# date
# 2016-01-15 00:00:00              70.541216                     127.092003
# 2016-01-15 01:00:00              69.266198                     125.629232
# 2016-01-15 02:00:00              68.116445                     123.819808
# 2016-01-15 03:00:00              68.347543                     122.270188
# 2016-01-15 04:00:00              66.927016                     117.988169
# ...                                    ...                            ...
# 2018-08-18 06:59:59              73.755150                     123.381787
# 2018-08-18 07:59:59              69.049291                     120.878188
# 2018-08-18 08:59:59              67.002189                     105.666118
# 2018-08-18 09:59:59              65.523246                      98.880538
# 2018-08-18 10:59:59              70.281454                      95.248427
#
#                      primary_cleaner.input.depressant  \
# date
# ...

# %%
drop_list_corr = df.columns.tolist()

# %%
data_train = data_train[drop_list_corr]

# %%
data_test = data_test[drop_list_corr]

# %%
plt.figure(figsize=(40,20), dpi= 80)
sns.heatmap(data_test.corr(), xticklabels=data_test.corr().columns, 
            yticklabels=data_test.corr().columns, cmap='RdYlGn', center=0, annot=True)


plt.title('Корреляция признаков', fontsize=22)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.show()

# %% [markdown]
# 1. Добавлены таргеты в тестовую df
# 2. Заполнены пропуски
# 3. Выявлены выбросы в целевых признаках и выброшены
# 4. Отброшены сильно коррелирующие признаки

# %% [markdown]
# ## Анализ данных

# %% [markdown]
# 2.1 Посмотрите, как меняется концентрация металлов (Au, Ag, Pb) на различных этапах очистки. Опишите выводы.
#
# 2.2 Сравните распределения размеров гранул сырья на обучающей и тестовой выборках. Если распределения сильно отличаются друг от друга, оценка модели будет неправильной.
#
# 2.3 Исследуйте суммарную концентрацию всех веществ на разных стадиях: в сырье, в черновом и финальном концентратах. Заметили аномальные значения в суммарном распределении или нет? Если они есть, стоит ли их удалять из обеих выборок? Опишите выводы и удалите аномалии.

# %%
rougher_concetarte = [ 'rougher.output.concentrate_ag',
 'rougher.output.concentrate_pb',
 'rougher.output.concentrate_au']

# %%
primary_concetarte = ['primary_cleaner.output.concentrate_ag',
 'primary_cleaner.output.concentrate_pb',
 'primary_cleaner.output.concentrate_au']

# %%
final_concetarte = ['final.output.concentrate_ag',
 'final.output.concentrate_pb',
 'final.output.concentrate_au']

# %%
def stage_rough(data, list_columns_1, list_columns_2, list_columns_4):
    for i in range(0, 3):
        if i == 0:
            for col in list_columns_1:
                mean = data[col].mean()
                print('Средняя концентрация металла {} на этапе primary_cleaner {: .2f}'.format(col, mean))
            print('')
        elif i == 1:
            for col in list_columns_2:
                mean = data[col].mean()
                print('Средняя концентрация металла {} на этапе primary_cleaner {: .2f}'.format(col, mean))
            print('')
        elif i == 2:
            for col in list_columns_4:
                mean = data[col].mean()
                print('Средняя концентрация металла {} на этапе final.output {: .2f}'.format(col, mean))

# %%
stage_rough(data_full, rougher_concetarte, primary_concetarte, final_concetarte)
# Out:
# Средняя концентрация металла rougher.output.concentrate_ag на этапе primary_cleaner  10.85
# Средняя концентрация металла rougher.output.concentrate_pb на этапе primary_cleaner  6.89
# Средняя концентрация металла rougher.output.concentrate_au на этапе primary_cleaner  17.83
#
# Средняя концентрация металла primary_cleaner.output.concentrate_ag на этапе primary_cleaner  7.67
# Средняя концентрация металла primary_cleaner.output.concentrate_pb на этапе primary_cleaner  8.81
# Средняя концентрация металла primary_cleaner.output.concentrate_au на этапе primary_cleaner  29.12
#
# Средняя концентрация металла final.output.concentrate_ag на этапе final.output  4.77
# Средняя концентрация металла final.output.concentrate_pb на этапе final.output  9.07
# Средняя концентрация металла final.output.concentrate_au на этапе final.output  39.89

# %% [markdown]
# **Средняя концетрация золота растет от этапа к этапу, в свою очередь концетрация остальных металлов падает.
# Значит процессы флотации и первичной и вторичной очистки работают исправно, процесс идет без аномалий.**

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
sns.set_style("white")


df = data_full
x1 = df['rougher.output.concentrate_au'].dropna()
x2 = df['primary_cleaner.output.concentrate_au'].dropna()
x3 = df['final.output.concentrate_au'].dropna()


kwargs = dict(hist_kws={'alpha':.6}, kde_kws={'linewidth':2})

plt.figure(figsize=(10,7), dpi= 80)
sns.distplot(x1, color="dodgerblue", label="Флотация")
sns.distplot(x2, color="orange", label="Первичная очистка")
sns.distplot(x3, color="deeppink", label="Финальный продукт")
plt.xlabel('процент вещества')
plt.legend();
plt.title('Распределение концетрации золота (Au) на различных этапах');

# %% [markdown]
# **2.2 Сравните распределения размеров гранул сырья на обучающей и тестовой выборках. Если распределения сильно отличаются друг от друга, оценка модели будет неправильной.**

# %%
sns.displot(data=data_train['primary_cleaner.input.feed_size'], height=9)

# %%
sns.displot(data=data_test['primary_cleaner.input.feed_size'], height=9)

# %% [markdown]
# **Распределение гранул сырья после первичной очистки и в тренировочном и в тестовом df выглядят как нормальное рапределение**

# %%
sns.displot(data=data_train['rougher.input.feed_size'], height=9)

# %%
sns.displot(data=data_test['rougher.input.feed_size'], height=9)

# %% [markdown]
# **Распределение гранул на этапе флотации не похоже на нормальное и стоит провести тест на нормальность распределение, если визуально это не определить.**

# %%
import statsmodels.api as sm
from matplotlib import pyplot as plt


sm.qqplot(data_test['rougher.input.feed_size'], line='s')
plt.show()

sm.qqplot(data_train['rougher.input.feed_size'], line='s')
plt.show()

# %%
samples_A = data_train['rougher.input.feed_size']
samples_B = data_test['rougher.input.feed_size']

# %%
# фактическая разность средних значений в группах
AB_difference = samples_B.mean() - samples_A.mean()
print("Разность средних размеров гранул:", AB_difference)

alpha = 0.05
    
state = np.random.RandomState(12345)

bootstrap_samples = 1000
count = 0
for i in range(bootstrap_samples):
    # объедините выборки
    united_samples = pd.concat([samples_A, samples_B])

    # создайте подвыборку
    subsample = united_samples.sample(frac=1, replace=True, random_state=state)
    
    # разбейте подвыборку пополам
    subsample_A = subsample[:len(samples_A)]
    subsample_B = subsample[len(samples_A):]
    # найдите разницу средних
    bootstrap_difference = subsample_B.mean() - subsample_A.mean()
    
    # если разница не меньше фактической, увеличиваем счётчик
    if bootstrap_difference >= AB_difference:
        count += 1

# p-value равно доле превышений значений
pvalue = 1. * count / bootstrap_samples
print('p-value =', pvalue)

if pvalue < alpha:
    print("Отвергаем нулевую гипотезу: скорее всего, средний размер гранул отличается")
else:
    print("Не получилось отвергнуть нулевую гипотезу: скорее всего, средний размер гранул не отличается")
# Out:
# Разность средних размеров гранул: -4.256176175754156
# p-value = 1.0
# Не получилось отвергнуть нулевую гипотезу: скорее всего, средний размер гранул не отличается

# %%
data_test_var = np.var(data_test['rougher.input.feed_size'], ddof=1)
data_train_var = np.var(data_train['rougher.input.feed_size'], ddof=1)

# %% [markdown]
# **Проверим дисперсии**

# %%
data_test_var, data_train_var
# Out:
# (513.6869235968859, 910.4537657676448)

# %% [markdown]
# **Равен ли средний размер гранул test_df и train_df?**

# %%
from scipy import stats as st
np.random.seed(12345678)

rvs1 = data_train['rougher.input.feed_size']
rvs2 = data_test['rougher.input.feed_size']

alpha = 0.05

results =  st.ttest_ind(
    rvs1,
    rvs2,
    equal_var=False,)


print('p-значение:', results.pvalue)

if results.pvalue < alpha:
    print("Отвергаем нулевую гипотезу, средний размер гранул отличается")
else:
    print("Не получилось отвергнуть нулевую гипотезу, скорее всего, средний размер гранул не отличается")
# Out:
# p-значение: 1.4743342939269116e-28
# Отвергаем нулевую гипотезу, средний размер гранул отличается

# %% [markdown]
# 1. Чисто визуально размер гранул на этапе флотации не выглядит как нормальное распределение, различные тесты тоже склоняются больше к не нормальному распределению.
# 2. Посел флотации распределение нормальное
# 3. Будем считать, что распределение стремиться к нормальному
#
# ____
#
# Хотя распределение для тестовой выборки немного отличается от такового для обучающей. Первое сдвинуто немного в меньшую сторону (как мода, так и среднее), также более ярко выделена мода, однако в целом размеры большинства частиц лежат в оптимальном интервале 40—100 мкм («Флотация руды»: ООО "Техноаналитприбор":[сайт].URL:https://techade.ru/stati/flotatsiya-rudy) для обоих выборок. Так что тестовая выборка подходит для оценки.

# %% [markdown]
# **2.3 Исследуйте суммарную концентрацию всех веществ на разных стадиях: в сырье, в черновом и финальном концентратах. Заметили аномальные значения в суммарном распределении или нет? Если они есть, стоит ли их удалять из обеих выборок? Опишите выводы и удалите аномалии.**

# %%
concetrate_dict = {'rougher' : [x for x in data_full.columns if x.startswith('rougher.output.concentrate')],
                   'primary' : [x for x in data_full.columns if x.startswith('primary_cleaner.output')],
                   'final' : [x for x in data_full.columns if x.startswith('final.output.concentrate')]}

# %%
for key in concetrate_dict:
    sns.displot(data = np.sum(data_full[concetrate_dict[key]], axis=1))
    plt.title(f'Cуммарная концентрация всех веществ на стадии {key}')

# %% [markdown]
# 1. Есть заметные выбросы в районе 0 на этапах rougher и primary.
# 2. В целом распределения нормальные и ближе к финальному этапу концентрируется сильнее вокруг одного значения.
# 3. Данных столбцов нет в train и test выборках, поэтому можно не выкидывать из, т.к. они содержаться только в полном df

# %% [markdown]
# ## Модель

# %% [markdown]
# 3.1 Напишите функцию для вычисления итоговой sMAPE.
#
# 3.2 Обучите разные модели и оцените их качество кросс-валидацией. Выберите лучшую модель и проверьте её на тестовой выборке. Опишите выводы.

# %%
droplist = data_train.columns.tolist()
droplist
# Out:
# ['final.output.recovery',
#  'primary_cleaner.input.sulfate',
#  'primary_cleaner.input.depressant',
#  'primary_cleaner.input.feed_size',
#  'primary_cleaner.input.xanthate',
#  'primary_cleaner.state.floatbank8_a_air',
#  'primary_cleaner.state.floatbank8_d_level',
#  'rougher.input.feed_ag',
#  'rougher.input.feed_pb',
#  'rougher.input.feed_rate',
#  'rougher.input.feed_size',
#  'rougher.input.floatbank10_sulfate',
#  'rougher.input.floatbank11_xanthate',
#  'rougher.output.recovery',
#  'rougher.state.floatbank10_a_air',
#  'rougher.state.floatbank10_a_level',
#  'rougher.state.floatbank10_b_air',
#  'rougher.state.floatbank10_b_level',
#  'secondary_cleaner.state.floatbank2_a_air',
#  'secondary_cleaner.state.floatbank2_a_level',
#  'secondary_cleaner.state.floatbank3_a_air',
#  'secondary_cleaner.state.floatbank3_a_level',
#  'secondary_cleaner.state.floatbank4_a_air',
#  'secondary_cleaner.state.floatbank4_a_level',
#  'secondary_cleaner.state.floatbank4_b_level',
# ...

# %%
rough_drop_list = [ 'secondary_cleaner.state.floatbank2_a_air',
 'secondary_cleaner.state.floatbank2_a_level',
 'secondary_cleaner.state.floatbank3_a_air',
 'secondary_cleaner.state.floatbank3_a_level',
 'secondary_cleaner.state.floatbank4_a_air',
 'secondary_cleaner.state.floatbank4_a_level',
 'secondary_cleaner.state.floatbank4_b_level',
 'secondary_cleaner.state.floatbank5_b_air',
 'secondary_cleaner.state.floatbank5_b_level',
 'secondary_cleaner.state.floatbank6_a_air',
 'secondary_cleaner.state.floatbank6_a_level',
                  'final.output.recovery',
 'primary_cleaner.input.sulfate',
 'primary_cleaner.input.depressant',
 'primary_cleaner.input.feed_size',
 'primary_cleaner.input.xanthate',
 'primary_cleaner.state.floatbank8_a_air',
 'primary_cleaner.state.floatbank8_d_level']

# %%
final_drop_list = ['rougher.output.recovery',
                   'final.output.recovery']

# %%
def sMAPE_final(smape_rough,smape_final):
    SMAPE = 0.25 * smape_rough + 0.75 * smape_final
    return abs(SMAPE)

# %%
def sMAPE(y_true, y_predict):
    smape = (abs(y_true - y_predict)/((abs(y_true) + abs(y_predict))/2)) * 100
    return smape.mean()

# %% [markdown]
# **3.2 Обучите разные модели и оцените их качество кросс-валидацией. Выберите лучшую модель и проверьте её на тестовой выборке. Опишите выводы.**

# %% [markdown]
# Данные для предсказания rougher.output.recovery

# %%
target_rough_train = data_train['rougher.output.recovery']
features_rough_train = data_train.drop(rough_drop_list , axis=1)
#
target_rough_test = data_test['rougher.output.recovery']
features_rough_test = data_test.drop(rough_drop_list , axis=1)

# %%
target_rough_train.shape, features_rough_train.shape, target_rough_test.shape, features_rough_test.shape
# Out:
# ((16187,), (16187, 11), (5678,), (5678, 11))

# %% [markdown]
# Данные для предсказания final.output.recovery

# %%
target_final_train = data_train['final.output.recovery']
features_final_train = data_train.drop(final_drop_list, axis=1)
#
target_final_test = data_test['final.output.recovery']
features_final_test = data_test.drop(final_drop_list , axis=1)

# %%
target_final_train.shape, features_final_train.shape, target_final_test.shape, features_final_test.shape
# Out:
# ((16187,), (16187, 27), (5678,), (5678, 27))

# %% [markdown]
# Создание переменной скоринга в cross_val_score

# %%
smape_scoring = make_scorer(sMAPE,  greater_is_better = False)

# %% [markdown]
# **Модели - Средние результаты оценка smape через cross_val_score**

# %% [markdown]
# LinearRegression

# %%
# %%time

model_rough = LinearRegression().fit(features_rough_train, target_rough_train)
model_final = LinearRegression().fit(features_final_train, target_final_train)

predict_rough = model_rough.predict(features_rough_test)
predict_final = model_final.predict(features_final_test)

LR_cross_score_rough = cross_val_score(model_rough, features_rough_train, target_rough_train, cv=5, scoring = smape_scoring)
LR_cross_score_final = cross_val_score(model_final, features_final_train, target_final_train, cv=5, scoring = smape_scoring)
sMAPE_final(LR_cross_score_rough,LR_cross_score_final).mean()
# Out:
# Wall time: 134 ms
# 9.120659051037672

# %% [markdown]
# RandomForestRegressor

# %%
# %%time
from sklearn.ensemble import RandomForestRegressor


best_model_rough = None
best_model_final = None
best_smape_RFR = 20

for depth in range(1,10, 1):
    model_rough = RandomForestRegressor(random_state=12345,
                                       n_estimators=100, max_depth=depth).fit(features_rough_train, target_rough_train)
    model_final = RandomForestRegressor(random_state=12345,
                                       n_estimators=100, max_depth=depth).fit(features_final_train, target_final_train) 
    RFR_cross_score_rough = cross_val_score(model_rough, features_rough_train, target_rough_train, cv=5, scoring = smape_scoring)
    RFR_cross_score_final = cross_val_score(model_final, features_final_train, target_final_train, cv=5, scoring = smape_scoring)
    smape_RFR = sMAPE_final(RFR_cross_score_rough,RFR_cross_score_final).mean()
    if smape_RFR < best_smape_RFR:
        best_model_rough = model_rough
        best_model_final = model_final
        best_smape_RFR = smape_RFR
                    
print("Итоговый sMAPE лучшей модели:", best_smape_RFR)
print("Лучшая модель для rough", best_model_rough, "Лучшая модель для final", best_model_final)
# Out:
# Итоговый sMAPE лучшей модели: 8.971328102992358
# Лучшая модель для rough RandomForestRegressor(max_depth=7, random_state=12345) Лучшая модель для final RandomForestRegressor(max_depth=7, random_state=12345)
# Wall time: 12min 27s

# %% [markdown]
# 11.27359390342399 до корреляции #1
#
# 10.858519919386731 до корреляции #2

# %%
best_model_rough_RFR = RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
                      max_depth=7, max_features='auto', max_leaf_nodes=None,
                      max_samples=None, min_impurity_decrease=0.0,
                      min_impurity_split=None, min_samples_leaf=1,
                      min_samples_split=2, min_weight_fraction_leaf=0.0,
                      n_estimators=100, n_jobs=None, oob_score=False,
                      random_state=12345, verbose=0, warm_start=False) 
best_model_final_RFR = RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
                      max_depth=7, max_features='auto', max_leaf_nodes=None,
                      max_samples=None, min_impurity_decrease=0.0,
                      min_impurity_split=None, min_samples_leaf=1,
                      min_samples_split=2, min_weight_fraction_leaf=0.0,
                      n_estimators=100, n_jobs=None, oob_score=False,
                      random_state=12345, verbose=0, warm_start=False)

# %% [markdown]
# DecisionTreeRegressor

# %%
# %%time
from sklearn.tree import DecisionTreeRegressor


best_model_rough_DTR = None
best_model_final_DTR = None
best_smape_DTR = 20

for depth in range(1,20, 1):
  for leaf in range(2, 20, 2):
    model_rough = DecisionTreeRegressor(random_state=12345, max_leaf_nodes=leaf, max_depth=depth).fit(features_rough_train, target_rough_train) 
    model_final = DecisionTreeRegressor(random_state=12345, max_leaf_nodes=leaf, max_depth=depth).fit(features_final_train, target_final_train) 
    DTR_cross_score_rough = cross_val_score(model_rough, features_rough_train, target_rough_train, cv=5, scoring = smape_scoring)
    DTR_cross_score_final = cross_val_score(model_final, features_final_train, target_final_train, cv=5, scoring = smape_scoring)
    
    smape_DTR = sMAPE_final(DTR_cross_score_rough,DTR_cross_score_final).mean()
    if smape_DTR < best_smape_DTR:
      best_model_rough_DTR = model_rough
      best_model_final_DTR = model_final
      best_smape_DTR = smape_DTR
                    
print("Итоговый sMAPE лучшей модели:", best_smape_DTR)
print("Лучшая модель для rough", best_model_rough_DTR, "Лучшая модель для final", best_model_final_DTR)
# Out:
# Итоговый sMAPE лучшей модели: 9.66536549893742
# Лучшая модель для rough DecisionTreeRegressor(max_depth=3, max_leaf_nodes=8, random_state=12345) Лучшая модель для final DecisionTreeRegressor(max_depth=3, max_leaf_nodes=8, random_state=12345)
# Wall time: 3min 27s

# %% [markdown]
# 11.661558343458655 до корреляции 1
#
# 10.941800971945547 до корреляции 2

# %%
#Лучшая модель для rough 
best_model_rough_DTR = DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=6,
                      max_features=None, max_leaf_nodes=8,
                      min_impurity_decrease=0.0, min_impurity_split=None,
                      min_samples_leaf=1, min_samples_split=2,
                      min_weight_fraction_leaf=0.0,
                      random_state=12345, splitter='best') 
#Лучшая модель для final
best_model_final_DTR = DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=6,
                      max_features=None, max_leaf_nodes=8,
                      min_impurity_decrease=0.0, min_impurity_split=None,
                      min_samples_leaf=1, min_samples_split=2,
                      min_weight_fraction_leaf=0.0,
                      random_state=12345, splitter='best')

# %% [markdown]
# MLPRegressor

# %%
# %%time
from sklearn.neural_network import MLPRegressor



best_model_rough_MPLR = None
best_model_final_MPLR = None
best_smape_MPLR = 20


for iters in range(1000, 10000, 1000):
  model_rough= MLPRegressor(random_state=12345, max_iter=iters).fit(features_rough_train, target_rough_train)
  model_final = MLPRegressor(random_state=12345, max_iter=iters).fit(features_final_train, target_final_train)
  MPLR_cross_score_rough = cross_val_score(model_rough, features_rough_train, target_rough_train, cv=5, scoring = smape_scoring)
  MPLR_cross_score_final = cross_val_score(model_final, features_final_train, target_final_train, cv=5, scoring = smape_scoring)

  smape_MPLS = sMAPE_final(MPLR_cross_score_rough,MPLR_cross_score_final).mean()
  if smape_MPLS < best_smape_MPLR:
    best_model_rough_MPLR = model_rough
    best_model_final_MPLR = model_final
    best_smape_MPLR = smape_MPLS
                    
print("Итоговый sMAPE лучшей модели:", best_smape_MPLR)
print("Лучшая модель для rough", best_model_rough_MPLR, "Лучшая модель для final", best_model_final_MPLR)
# Out:
# Итоговый sMAPE лучшей модели: 11.758884767073031
# Лучшая модель для rough MLPRegressor(max_iter=1000, random_state=12345) Лучшая модель для final MLPRegressor(max_iter=1000, random_state=12345)
# Wall time: 4min 26s

# %% [markdown]
# 15.645266739475687 до корреляции 1
#
# 13.081727598474895 до корреляции 2

# %%
#Лучшая модель для rough 
best_model_rough_MPLR = MLPRegressor(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
             beta_2=0.999, early_stopping=False, epsilon=1e-08,
             hidden_layer_sizes=(100,), learning_rate='constant',
             learning_rate_init=0.001, max_fun=15000, max_iter=1000,
             momentum=0.9, n_iter_no_change=10, nesterovs_momentum=True,
             power_t=0.5, random_state=12345, shuffle=True, solver='adam',
             tol=0.0001, validation_fraction=0.1, verbose=False,
             warm_start=False) 
#Лучшая модель для final 
best_model_final_MPLR = MLPRegressor(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
             beta_2=0.999, early_stopping=False, epsilon=1e-08,
             hidden_layer_sizes=(100,), learning_rate='constant',
             learning_rate_init=0.001, max_fun=15000, max_iter=1000,
             momentum=0.9, n_iter_no_change=10, nesterovs_momentum=True,
             power_t=0.5, random_state=12345, shuffle=True, solver='adam',
             tol=0.0001, validation_fraction=0.1, verbose=False,
             warm_start=False)

# %% [markdown]
# **Подчсет Итогового sMAPE на тестовой выборке по обученым моделям**

# %% [markdown]
# Модель для проверки на адекватность
# DummyRegressor

# %%
# %%time
from sklearn.dummy import DummyRegressor

#dummy_rough = DummyRegressor(strategy="constant", constant = 67).fit(features_rough_train, target_rough_train)
#dummy_final = DummyRegressor(strategy="constant", constant = 67).fit(features_final_train, target_final_train)
dummy_rough = DummyRegressor(strategy="constant", constant = 67).fit(features_rough_train, target_rough_train)
dummy_final = DummyRegressor(strategy="constant", constant = 67).fit(features_final_train, target_final_train)

dummy_predict_rough = dummy_rough.predict(features_rough_test)
dummy_predict_final = dummy_final.predict(features_final_test)

dummy_sMAPE_rough_LR = sMAPE(target_rough_test, dummy_predict_rough)
dummy_sMAPE_final_LR = sMAPE(target_final_test, dummy_predict_final)

dummy_result = sMAPE_final(dummy_sMAPE_rough_LR,dummy_sMAPE_final_LR)

print("Итоговый sMAPE на тестовом df для DummyRegressor: {}".format(dummy_result))
# Out:
# Итоговый sMAPE на тестовом df для DummyRegressor: 14.347237742243738
# Wall time: 5 ms

# %%
# %%time
from sklearn.dummy import DummyRegressor

#dummy_rough = DummyRegressor(strategy="constant", constant = 67).fit(features_rough_train, target_rough_train)
#dummy_final = DummyRegressor(strategy="constant", constant = 67).fit(features_final_train, target_final_train)
dummy_rough = DummyRegressor(strategy="median").fit(features_rough_train, target_rough_train)
dummy_final = DummyRegressor(strategy="median").fit(features_final_train, target_final_train)

dummy_predict_rough = dummy_rough.predict(features_rough_test)
dummy_predict_final = dummy_final.predict(features_final_test)

dummy_sMAPE_rough_LR = sMAPE(target_rough_test, dummy_predict_rough)
dummy_sMAPE_final_LR = sMAPE(target_final_test, dummy_predict_final)

dummy_result = sMAPE_final(dummy_sMAPE_rough_LR,dummy_sMAPE_final_LR)

print("Итоговый sMAPE на тестовом df для DummyRegressor: {}".format(dummy_result))
# Out:
# Итоговый sMAPE на тестовом df для DummyRegressor: 9.135493686519528
# Wall time: 6 ms

# %% [markdown]
# LinearRegression

# %%
# %%time
model_rough = LinearRegression().fit(features_rough_train, target_rough_train)
model_final = LinearRegression().fit(features_final_train, target_final_train)

predict_rough = model_rough.predict(features_rough_test)
predict_final = model_final.predict(features_final_test)

sMAPE_rough_LR = sMAPE(target_rough_test, predict_rough)
sMAPE_final_LR = sMAPE(target_final_test, predict_final)

LR_result = sMAPE_final(sMAPE_rough_LR,sMAPE_final_LR)
print("Итоговый sMAPE на тестовом df для LinearRegression: {}".format(LR_result))
# Out:
# Итоговый sMAPE на тестовом df для LinearRegression: 7.745472495661573
# Wall time: 19 ms

# %% [markdown]
# RandomForestRegressor

# %%
# %%time
best_model_rough_RFR = RandomForestRegressor(bootstrap=True, criterion='mse',
                      max_depth=7, max_features='auto', max_leaf_nodes=None, min_impurity_decrease=0.0,
                      min_impurity_split=None, min_samples_leaf=1,
                      min_samples_split=2, min_weight_fraction_leaf=0.0,
                      n_estimators=100, n_jobs=None, oob_score=False,
                      random_state=12345, verbose=0, warm_start=False).fit(features_rough_train, target_rough_train)
########################################################################################################
best_model_final_RFR = RandomForestRegressor(bootstrap=True, criterion='mse',
                      max_depth=7, max_features='auto', max_leaf_nodes=None, min_impurity_decrease=0.0,
                      min_impurity_split=None, min_samples_leaf=1,
                      min_samples_split=2, min_weight_fraction_leaf=0.0,
                      n_estimators=100, n_jobs=None, oob_score=False,
                      random_state=12345, verbose=0, warm_start=False).fit(features_final_train, target_final_train)

predict_rough = best_model_rough_RFR.predict(features_rough_test)
predict_final = best_model_final_RFR.predict(features_final_test)
sMAPE_final_RFR = sMAPE(target_final_test, predict_final)
sMAPE_rough_RFR = sMAPE(target_rough_test, predict_rough)
RFR_result = sMAPE_final(sMAPE_rough_RFR,sMAPE_final_RFR)
print("Итоговый sMAPE на тестовом df для RandomForestRegressor: {}".format(RFR_result))
# Out:
# Итоговый sMAPE на тестовом df для RandomForestRegressor: 8.337186899280505
# Wall time: 23.3 s

# %% [markdown]
# DecisionTreeRegressor

# %%
# %%time
best_model_rough_DTR = DecisionTreeRegressor(criterion='mse', max_depth=6, 
                                             max_features=None, max_leaf_nodes=8, min_impurity_decrease=0.0, 
                                             min_impurity_split=None, min_samples_leaf=1, min_samples_split=2,
                                             min_weight_fraction_leaf=0.0,random_state=12345, 
                                             splitter='best').fit(features_rough_train, target_rough_train)
########################################################################################################
best_model_final_DTR = DecisionTreeRegressor(criterion='mse', max_depth=6,
                      max_features=None, max_leaf_nodes=8,
                      min_impurity_decrease=0.0, min_impurity_split=None,
                      min_samples_leaf=1, min_samples_split=2,
                      min_weight_fraction_leaf=0.0,random_state=12345, 
                                             splitter='best').fit(features_final_train, target_final_train)

predict_rough = best_model_rough_DTR.predict(features_rough_test)
predict_final = best_model_final_DTR.predict(features_final_test)
sMAPE_final_DTR = sMAPE(target_final_test, predict_final)
sMAPE_rough_DTR = sMAPE(target_rough_test, predict_rough)
DTR_result = sMAPE_final(sMAPE_rough_DTR,sMAPE_final_DTR)

print("Итоговый sMAPE на тестовом df для DecisionTreeRegressor: {}".format(DTR_result))
# Out:
# Итоговый sMAPE на тестовом df для DecisionTreeRegressor: 8.613404280837127
# Wall time: 282 ms

# %% [markdown]
# MLPRegressor

# %%
# %%time
best_model_rough_MPLR = MLPRegressor(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
             beta_2=0.999, early_stopping=False, epsilon=1e-08,
             hidden_layer_sizes=(100,), learning_rate='constant',
             learning_rate_init=0.001, max_iter=1000,
             momentum=0.9, n_iter_no_change=10, nesterovs_momentum=True,
             power_t=0.5, random_state=12345, shuffle=True, solver='adam',
             tol=0.0001, validation_fraction=0.1, verbose=False,
             warm_start=False).fit(features_rough_train, target_rough_train)
########################################################################################################
best_model_final_MPLR = MLPRegressor(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
             beta_2=0.999, early_stopping=False, epsilon=1e-08,
             hidden_layer_sizes=(100,), learning_rate='constant',
             learning_rate_init=0.001, max_iter=1000,
             momentum=0.9, n_iter_no_change=10, nesterovs_momentum=True,
             power_t=0.5, random_state=12345, shuffle=True, solver='adam',
             tol=0.0001, validation_fraction=0.1, verbose=False,
             warm_start=False).fit(features_final_train, target_final_train)

predict_rough = best_model_rough_MPLR.predict(features_rough_test)
predict_final = best_model_final_MPLR.predict(features_final_test)
sMAPE_final_MPLR = sMAPE(target_final_test, predict_final)
sMAPE_rough_MPLR = sMAPE(target_rough_test, predict_rough)
MPLR_result = sMAPE_final(sMAPE_rough_MPLR,sMAPE_final_MPLR)
print("Итоговый sMAPE на тестовом df для MLPRegressor: {}".format(MPLR_result))
# Out:
# Итоговый sMAPE на тестовом df для MLPRegressor: 8.502875652679014
# Wall time: 5.2 s

# %% [markdown]
# **Сравнение результатов с константной моделью DummyRegression**

# %%
P_MPLR = ((dummy_result - MPLR_result) / dummy_result) *100
print(f'MLPRegressor лучше DummyRegression на {P_MPLR} %')
# Out:
# MLPRegressor лучше DummyRegression на 6.924836856644257 %

# %%
P_DTR = ((dummy_result - DTR_result) / dummy_result) *100
print(f'DecisionTreeRegressor лучше DummyRegression на {P_DTR} %')
# Out:
# DecisionTreeRegressor лучше DummyRegression на 5.714955574352854 %

# %%
P_RFR = ((dummy_result - RFR_result) / dummy_result) *100
print(f'RandomForestRegressor лучше DummyRegression на {P_RFR} %')
# Out:
# RandomForestRegressor лучше DummyRegression на 8.738518296137801 %

# %%
P_LR = ((dummy_result - LR_result) / dummy_result) *100
print(f'LinearRegression лучше DummyRegression на {P_LR} %')
# Out:
# LinearRegression лучше DummyRegression на 15.215611094002412 %

# %% [markdown]
# **Лучший результат на тестовой выборке показала LinearRegression:**
#
# Итоговый sMAPE = 7.745472495661584
#
# Лучше DummyRegression на 15.215611094002254 %

# %% [markdown]
# - [x]  Выполнен шаг 1: данные подготовлены
#     - [x]  Проверена формула вычисления эффективности обогащения
#     - [x]  Проанализированы признаки, недоступные в тестовой выборке
#     - [x]  Проведена предобработка данных
# - [x]  Выполнен шаг 2: данные проанализированы
#     - [x]  Исследовано изменение концентрации элементов на каждом этапе
#     - [x]  Проанализированы распределения размеров гранул на обучающей и тестовой выборках
#     - [x]  Исследованы суммарные концентрации
#     - [x]  Проанализированы и обработаны аномальные значения
# - [x]  Выполнен шаг 3: построена модель прогнозирования
#     - [x]  Написана функция для вычисления итогового *sMAPE*
#     - [x]  Обучено и проверено несколько моделей
#     - [x]  Выбрана лучшая модель, её качество проверено на тестовой выборке
